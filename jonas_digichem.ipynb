# %% [markdown]
# <a href="https://colab.research.google.com/github/goetzdominik/Digichem/blob/main/jonas_digichem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade numpy
# !pip install --upgrade mendeleev
# !pip install --upgrade pymatgen
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Collecting numpy
#   Downloading numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 923.3 kB/s eta 0:00:00
# Downloading numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 19.9 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.5 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.5 which is incompatible.
# Successfully installed numpy-2.2.5
# Collecting mendeleev
#   Downloading mendeleev-1.0.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: Pygments<3.0.0,>=2.11.2 in /usr/local/lib/python3.11/dist-packages (from mendeleev) (2.19.1)
# Requirement already satisfied: SQLAlchemy>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mendeleev) (2.0.40)
# Collecting colorama<0.5.0,>=0.4.6 (from mendeleev)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: deprecated<2.0.0,>=1.2.14 in /usr/local/lib/python3.11/dist-packages (from mendeleev) (1.2.18)
# Collecting numpy<2.0,>=1.21 (from mendeleev)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from mendeleev) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from mendeleev) (2.11.4)
# Collecting pyfiglet<0.9,>=0.8.post1 (from mendeleev)
#   Downloading pyfiglet-0.8.post1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated<2.0.0,>=1.2.14->mendeleev) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->mendeleev) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->mendeleev) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->mendeleev) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.9.2->mendeleev) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.9.2->mendeleev) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.9.2->mendeleev) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.9.2->mendeleev) (0.4.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=1.4.0->mendeleev) (3.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->mendeleev) (1.17.0)
# Downloading mendeleev-1.0.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 28.2 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 59.4 MB/s eta 0:00:00
# Downloading pyfiglet-0.8.post1-py2.py3-none-any.whl (865 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.8/865.8 kB 23.9 MB/s eta 0:00:00
# Installing collected packages: pyfiglet, numpy, colorama, mendeleev
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.5
#     Uninstalling numpy-2.2.5:
#       Successfully uninstalled numpy-2.2.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed colorama-0.4.6 mendeleev-1.0.0 numpy-1.26.4 pyfiglet-0.8.post1
# Collecting pymatgen
#   Downloading pymatgen-2025.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (1.5.0)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (3.10.0)
# Collecting monty>=2025.1.9 (from pymatgen)
#   Downloading monty-2025.3.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (3.4.2)
# Collecting palettable>=3.3.3 (from pymatgen)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pandas>=2 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (2.2.2)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (5.24.1)
# Collecting bibtexparser>=1.4.0 (from pymatgen)
#   Downloading bibtexparser-1.4.3.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.32 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (2.32.3)
# Collecting ruamel.yaml>=0.17.0 (from pymatgen)
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (1.15.3)
# Collecting spglib>=2.5 (from pymatgen)
#   Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (1.13.1)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (0.9.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (4.67.1)
# Collecting uncertainties>=3.1.4 (from pymatgen)
#   Downloading uncertainties-3.2.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy<3,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (1.26.4)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from bibtexparser>=1.4.0->pymatgen) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2->pymatgen) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2->pymatgen) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->pymatgen) (9.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->pymatgen) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->pymatgen) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->pymatgen) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->pymatgen) (2025.4.26)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->pymatgen)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from spglib>=2.5->pymatgen) (4.13.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.3->pymatgen) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8->pymatgen) (1.17.0)
# Downloading pymatgen-2025.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 56.5 MB/s eta 0:00:00
# Downloading monty-2025.3.3-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 4.0 MB/s eta 0:00:00
# Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 23.5 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 9.3 MB/s eta 0:00:00
# Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (809 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.0/809.0 kB 47.0 MB/s eta 0:00:00
# Downloading uncertainties-3.2.3-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 3.8 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 43.6 MB/s eta 0:00:00
# Building wheels for collected packages: bibtexparser
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.3-py3-none-any.whl size=43549 sha256=3faae5eac66432f4a5d16b6d976280e37043e3be1c439a170498ffea054cfb6b
#   Stored in directory: /root/.cache/pip/wheels/16/fb/76/306387739cf9d53b1c39b0c8aadbbb17dc05f256756d8fd915
# Successfully built bibtexparser
# Installing collected packages: uncertainties, spglib, ruamel.yaml.clib, palettable, bibtexparser, ruamel.yaml, monty, pymatgen
# Successfully installed bibtexparser-1.4.3 monty-2025.3.3 palettable-3.3.3 pymatgen-2025.5.2 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12 spglib-2.6.0 uncertainties-3.2.3

# %%
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting pandas
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 98.4 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# Successfully installed pandas-2.2.3

# %%
# !pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2025.3.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.2.1)
# Downloading rdkit-2025.3.2-cp311-cp311-manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 34.6 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.3.2

# %%
import pandas as pd
import numpy as np
import pymatgen
from pymatgen.core import Element
from mendeleev import element

import ast

pd.set_option('display.max_rows', 100)  # Display 10 rows
pd.set_option('display.max_columns', None)  # Display all columns

# %%
#test mendeleev package
Fe = element("Fe")

print(Fe.fusion_heat)
print(Fe.evaporation_heat)
print(Fe.specific_heat)
print(Fe.electrons)
# Out:
# 13.8
# 340.0
# 0.449
# 26

# %%
#test pymatgen package
element = Element("Fe")  # Iron

print(element.Z)
print(element.group)
print(element.row)
print(element.mendeleev_no)
print(element.iupac_ordering)
print(element.average_ionic_radius)
print(element.atomic_radius)
print(element.atomic_radius_calculated)
print(element.van_der_waals_radius)
print(element.X)
print(element.electron_affinity)
print(element.ionization_energy)
print(element.valence[1])
print(element.atomic_mass)
print(element.density_of_solid)
print(element.molar_volume)
print(element.boiling_point)
print(element.melting_point)
print(element.thermal_conductivity)
# Out:
# 26
# 8
# 4
# 61.0
# 64
# 0.8525 ang
# 1.4 ang
# 1.56 ang
# 2.04 ang
# 1.83
# 0.15323635
# 7.9024681
# 6
# 55.845 amu
# 7874.0 kg m^-3
# 7.09 cm^3
# 3134.0 K
# 1811.0 K
# 80.0 W K^-1 m^-1

# %%
#add the missing values to the mendeleev functions of fusion heat, evaporation heat and specific heat (and BP)
missing_fusion_heats = {
    "As": 24.44,  # kJ/mol
    "O" : 0.44,
    "N" : 0.72,
    "C" : 117,
    "Ru" : 38.59,
    "Tb" : 10.15,
    "Gd" : 10.05,
    "Dy" : 11.06,
    "Eu" : 9.21,
    "Ho" : 17.0,
    "Er" : 19.9,
    "Lu" : 22,
    "Tm" : 16.84
}

from mendeleev import element

def get_fusion_heat(element_symbol):
    elmt = element(element_symbol)
    if elmt.fusion_heat is None and element_symbol in missing_fusion_heats:
        return missing_fusion_heats[element_symbol]
    elif elmt.fusion_heat is None and element_symbol not in missing_fusion_heats:
        print(elmt.name, "is missing fusion heat value")
    else:
        return elmt.fusion_heat

missing_evaporation_heats = {
    "O" : 6.82, # kJ/mol
    "N" : 5.58,
    "C" : 715,
    "Ru" : 619,
    "Tb" : 391
}

from mendeleev import element

def get_evaporation_heat(element_symbol):
    elmt = element(element_symbol)
    if elmt.evaporation_heat is None and element_symbol in missing_evaporation_heats:
        return missing_evaporation_heats[element_symbol]
    else:
        return elmt.evaporation_heat

missing_specific_heats = {
    "Pa" : 99.1,
    "Tc" : 63
}

def get_specific_heat(element_symbol):
    elmt = element(element_symbol)
    if elmt.specific_heat is None and element_symbol in missing_specific_heats:
        return missing_specific_heats[element_symbol]
    else:
        return elmt.specific_heat

def get_boiling_point(element_symbol):
    elmt = element(element_symbol)
    if element_symbol == "Pa":
        return 4000
    elif element_symbol == "P":
        return 550
    else:
        return elmt.boiling_point

# %%
#define function to handle missing values (use atomic radius instead of calculated and use atomic mass/molar volume instead of density of solid)
def get_atomic_radius_calculated(elmt_pymatgen_temp):
    atomic_radius_calculated_temp = elmt_pymatgen_temp.atomic_radius_calculated
    if atomic_radius_calculated_temp == None:
        return elmt_pymatgen_temp.atomic_radius
    else :
      return atomic_radius_calculated_temp

def get_density_of_solid(elmt_pymatgen_temp):
    density_of_solid_temp = elmt_pymatgen_temp.density_of_solid
    if density_of_solid_temp == None:
        return elmt_pymatgen_temp.atomic_mass / elmt_pymatgen_temp.molar_volume *1000
    else :
      return density_of_solid_temp

# %%
#define function to get number of valence electrons
from rdkit.Chem import GetPeriodicTable

# Create an instance of PeriodicTable
pt = GetPeriodicTable()

def get_valence(element_symbol):
  valence = pt.GetNOuterElecs(element_symbol)
  return valence

# %%
#create dictionary with the values for all elements (so that the loop over all formulas is faster) (takes approx 4 minutes now)

#find all elements in the csv file to create input for dictionary creation
elements_list = pd.read_csv('A2BCX6_filtered.csv', usecols= ['elements'])
elements_vector = []
for index in elements_list.index: # Iterate over DataFrame index to get row
  formula = elements_list.loc[index, 'elements'] # Access element string using loc
  formula = ast.literal_eval(formula) # Safely evaluate string as list
  for elmt in formula:
    elements_vector.append(elmt)

elements_vector = pd.Series(elements_vector).drop_duplicates().tolist() # Deduplicate elements


#loop over the found unique elements and define the needed properties
elemental_properties = {}  #dictionary to be filled

for symbol in elements_vector:
    #define strings as "elements"
    elmt_pymatgen = Element(symbol)
    elmt_mendeleev = element(symbol)

    properties = {
        'atomic_mass': elmt_pymatgen.atomic_mass,
        'Z': elmt_pymatgen.Z,
        'group': elmt_pymatgen.group,
        'fusion_heat': get_fusion_heat(symbol),  # Use custom function
        'evaporation_heat': get_evaporation_heat(symbol),  # Use custom function
        'specific_heat': get_specific_heat(symbol), # Use custom function
        'row': elmt_pymatgen.row,
        'mendeleev_no': elmt_pymatgen.mendeleev_no,
        'iupac_ordering': elmt_pymatgen.iupac_ordering,
        'average_ionic_radius': elmt_pymatgen.average_ionic_radius,
        'atomic_radius': elmt_pymatgen.atomic_radius,
        'atomic_radius_calculated': get_atomic_radius_calculated(elmt_pymatgen), # Use custom function
        'van_der_waals_radius': elmt_pymatgen.van_der_waals_radius,
        'X': elmt_pymatgen.X,
        'electron_affinity': elmt_pymatgen.electron_affinity,
        'ionization_energy': elmt_pymatgen.ionization_energy,
        'valence': get_valence(symbol), # Use custom function
        'density_of_solid': get_density_of_solid(elmt_pymatgen), # Use custom function
        'molar_volume': elmt_pymatgen.molar_volume,
        'boiling_point': get_boiling_point(symbol), # Use custom function
        'melting_point': elmt_pymatgen.melting_point,
        'thermal_conductivity': elmt_pymatgen.thermal_conductivity

    }

    elemental_properties[symbol] = properties  # For dictionary
# Out:
# <ipython-input-3-9fc867475506>:10: UserWarning: No data available for density_of_solid for F
#   density_of_solid_temp = elmt_pymatgen_temp.density_of_solid
# <ipython-input-3-9fc867475506>:10: UserWarning: No data available for density_of_solid for Cl
#   density_of_solid_temp = elmt_pymatgen_temp.density_of_solid
# <ipython-input-3-9fc867475506>:10: UserWarning: No data available for density_of_solid for O
#   density_of_solid_temp = elmt_pymatgen_temp.density_of_solid
# <ipython-input-3-9fc867475506>:10: UserWarning: No data available for density_of_solid for N
#   density_of_solid_temp = elmt_pymatgen_temp.density_of_solid
# <ipython-input-3-9fc867475506>:10: UserWarning: No data available for density_of_solid for H
#   density_of_solid_temp = elmt_pymatgen_temp.density_of_solid
# <ipython-input-3-9fc867475506>:3: UserWarning: No data available for atomic_radius_calculated for U
#   atomic_radius_calculated_temp = elmt_pymatgen_temp.atomic_radius_calculated
# <ipython-input-3-9fc867475506>:3: UserWarning: No data available for atomic_radius_calculated for Ce
#   atomic_radius_calculated_temp = elmt_pymatgen_temp.atomic_radius_calculated
# <ipython-input-3-9fc867475506>:3: UserWarning: No data available for atomic_radius_calculated for Ho
#   atomic_radius_calculated_temp = elmt_pymatgen_temp.atomic_radius_calculated
# <ipython-input-3-9fc867475506>:3: UserWarning: No data available for atomic_radius_calculated for La
#   atomic_radius_calculated_temp = elmt_pymatgen_temp.atomic_radius_calculated
# <ipython-input-3-9fc867475506>:10: UserWarning: No data available for density_of_solid for Hg
#   density_of_solid_temp = elmt_pymatgen_temp.density_of_solid
# <ipython-input-3-9fc867475506>:10: UserWarning: No data available for density_of_solid for Br
#   density_of_solid_temp = elmt_pymatgen_temp.density_of_solid
# <ipython-input-3-9fc867475506>:3: UserWarning: No data available for atomic_radius_calculated for Th
#   atomic_radius_calculated_temp = elmt_pymatgen_temp.atomic_radius_calculated

# %%
from pymatgen.core import Composition
#get only relevant columns from materials project file
df = pd.read_csv('A2BCX6_filtered.csv', usecols= ['formula_pretty','elements', 'band_gap','energy_above_hull','formation_energy_per_atom','density'])

#loop over all entries and extract the corresponding elements
index = -1
for formula in df["elements"]:
  index += 1
  comp = Composition(df["formula_pretty"][index])
  #reformat to list
  elements = ast.literal_eval(formula)

  #calculate property and mean/sd
  atomic_mass = []
  Z = []
  group = []
  row = []
  mendeleev_no = []
  iupac_ordering = []
  average_ionic_radius = []
  atomic_radius = []
  atomic_radius_calculated = []
  van_der_waals_radius = []
  X = []
  electron_affinity = []
  ionization_energy = []
  valence = []
  atomic_mass = []
  density_of_solid = []
  molar_volume = []
  fusion_heat = []
  evaporation_heat = []
  specific_heat = []

#use the library to assign the properties
  for elmt in elements:
    elmt_pymatgen = Element(elmt)
    element_amount = comp[elmt_pymatgen]
    counter = element_amount
    #loop over the number of times the specific element occurs in the formula so that mean and sd are correct
    while counter > 0:
      atomic_mass.append(elemental_properties[elmt]['atomic_mass'])
      Z.append(elemental_properties[elmt]['Z'])
      group.append(elemental_properties[elmt]['group'])
      row.append(elemental_properties[elmt]['row'])
      mendeleev_no.append(elemental_properties[elmt]['mendeleev_no'])
      iupac_ordering.append(elemental_properties[elmt]['iupac_ordering'])
      average_ionic_radius.append(elemental_properties[elmt]['average_ionic_radius'])
      atomic_radius.append(elemental_properties[elmt]['atomic_radius'])
      atomic_radius_calculated.append(elemental_properties[elmt]['atomic_radius_calculated'])
      van_der_waals_radius.append(elemental_properties[elmt]['van_der_waals_radius'])
      X.append(elemental_properties[elmt]['X'])
      electron_affinity.append(elemental_properties[elmt]['electron_affinity'])
      ionization_energy.append(elemental_properties[elmt]['ionization_energy'])
      valence.append(elemental_properties[elmt]['valence'])
      density_of_solid.append(elemental_properties[elmt]['density_of_solid'])
      molar_volume.append(elemental_properties[elmt]['molar_volume'])
      fusion_heat.append(elemental_properties[elmt]['fusion_heat'])
      evaporation_heat.append(elemental_properties[elmt]['evaporation_heat'])
      specific_heat.append(elemental_properties[elmt]['specific_heat'])
      counter -= 1

  mean_atomic_mass = np.mean(atomic_mass)
  std_atomic_mass = np.std(atomic_mass)
  mean_Z = np.mean(Z)
  std_Z = np.std(Z)
  mean_group = np.mean(group)
  std_group = np.std(group)
  mean_row = np.mean(row)
  std_row = np.std(row)
  mean_mendeleev_no = np.mean(mendeleev_no)
  std_mendeleev_no = np.std(mendeleev_no)
  mean_iupac_ordering = np.mean(iupac_ordering)
  std_iupac_ordering = np.std(iupac_ordering)
  mean_average_ionic_radius = np.mean(average_ionic_radius)
  std_average_ionic_radius = np.std(average_ionic_radius)
  mean_atomic_radius = np.mean(atomic_radius)
  std_atomic_radius = np.std(atomic_radius)
  mean_atomic_radius_calculated = np.mean(atomic_radius_calculated)
  std_atomic_radius_calculated = np.std(atomic_radius_calculated)
  mean_van_der_waals_radius = np.mean(van_der_waals_radius)
  std_van_der_waals_radius = np.std(van_der_waals_radius)
  mean_X = np.mean(X)
  std_X = np.std(X)
  mean_electron_affinity = np.mean(electron_affinity)
  std_electron_affinity = np.std(electron_affinity)
  mean_ionization_energy = np.mean(ionization_energy)
  std_ionization_energy = np.std(ionization_energy)
  mean_valence = np.mean(valence)
  std_valence = np.std(valence)
  mean_density_of_solid = np.mean(density_of_solid)
  std_density_of_solid = np.std(density_of_solid)
  mean_molar_volume = np.mean(molar_volume)
  std_molar_volume = np.std(molar_volume)
  mean_fusion_heat = np.mean(fusion_heat)
  std_fusion_heat = np.std(fusion_heat)
  mean_evaporation_heat = np.mean(evaporation_heat)
  std_evaporation_heat = np.std(evaporation_heat)
  mean_specific_heat = np.mean(specific_heat)
  std_specific_heat = np.std(specific_heat)

  #add to dataframe
  df.at[index, 'atom_mass_mean'] = mean_atomic_mass
  df.at[index, 'atom_mass_std'] = std_atomic_mass
  df.at[index, 'Z_mean'] = mean_Z
  df.at[index, 'Z_std'] = std_Z
  df.at[index, 'group_mean'] = mean_group
  df.at[index, 'group_std'] = std_group
  df.at[index, 'row_mean'] = mean_row
  df.at[index, 'row_std'] = std_row
  df.at[index, 'mendeleev_no_mean'] = mean_mendeleev_no
  df.at[index, 'mendeleev_no_std'] = std_mendeleev_no
  df.at[index, 'iupac_ordering_mean'] = mean_iupac_ordering
  df.at[index, 'iupac_ordering_std'] = std_iupac_ordering
  df.at[index, 'average_ionic_radius_mean'] = mean_average_ionic_radius
  df.at[index, 'average_ionic_radius_std'] = std_average_ionic_radius
  df.at[index, 'atomic_radius_mean'] = mean_atomic_radius
  df.at[index, 'atomic_radius_std'] = std_atomic_radius
  df.at[index, 'atomic_radius_calculated_mean'] = mean_atomic_radius_calculated
  df.at[index, 'atomic_radius_calculated_std'] = std_atomic_radius_calculated
  df.at[index, 'van_der_waals_radius_mean'] = mean_van_der_waals_radius
  df.at[index, 'van_der_waals_radius_std'] = std_van_der_waals_radius
  df.at[index, 'X_mean'] = mean_X
  df.at[index, 'X_std'] = std_X
  df.at[index, 'electron_affinity_mean'] = mean_electron_affinity
  df.at[index, 'electron_affinity_std'] = std_electron_affinity
  df.at[index, 'ionization_energy_mean'] = mean_ionization_energy
  df.at[index, 'ionization_energy_std'] = std_ionization_energy
  df.at[index, 'valence_mean'] = mean_valence
  df.at[index, 'valence_std'] = std_valence
  df.at[index, 'density_of_solid_mean'] = mean_density_of_solid
  df.at[index, 'density_of_solid_std'] = std_density_of_solid
  df.at[index, 'molar_volume_mean'] = mean_molar_volume
  df.at[index, 'molar_volume_std'] = std_molar_volume
  df.at[index, 'fusion_heat_mean'] = mean_fusion_heat
  df.at[index, 'fusion_heat_std'] = std_fusion_heat
  df.at[index, 'evaporation_heat_mean'] = mean_evaporation_heat
  df.at[index, 'evaporation_heat_std'] = std_evaporation_heat
  df.at[index, 'specific_heat_mean'] = mean_specific_heat
  df.at[index, 'specific_heat_std'] = std_specific_heat
# Display the updated dataframe
df
# Out:
#                     elements formula_pretty   density  \
# 0     ['Ag', 'Bi', 'P', 'S']     AgBi(PS3)2  4.147866
# 1    ['Ag', 'Bi', 'P', 'Se']    AgBi(PSe3)2  4.996192
# 2    ['Ag', 'F', 'Sb', 'Se']    AgSb(SeF3)2  4.168745
# 3    ['Al', 'Cl', 'O', 'Sn']      Al2SnCl6O  2.290229
# 4     ['Al', 'Cl', 'N', 'S']       AlS2NCl6  1.790779
# ..                       ...            ...       ...
# 601   ['O', 'Pb', 'Sb', 'Y']     YSb(PbO3)2  8.101840
# 602   ['P', 'Se', 'Tl', 'Y']     YTl(PSe3)2  5.046701
# 603  ['Dy', 'Pr', 'S', 'Yb']      Yb2PrDyS6  6.046102
# 604   ['Bi', 'O', 'P', 'Zn']       Zn2BiPO6  6.033975
# 605    ['C', 'O', 'P', 'Zr']        ZrP2CO6  2.720892
#
#      formation_energy_per_atom  energy_above_hull  band_gap  atom_mass_mean  \
# 0                    -0.338825           0.000000    1.1838       57.118612
# 1                    -0.465881           0.000000    1.2778       85.255612
# 2                    -1.916777           0.001239    1.1750       50.153862
# 3                    -2.081237           0.000000    3.9866       40.139048
# 4                    -0.766423           0.012674    1.7401       31.783624
# ..                         ...                ...       ...             ...
# 601                  -2.281386           0.022194    2.2943       72.106225
# 602                  -0.907077           0.000000    1.5071       82.899667
# 603                  -2.405468           0.000000    1.2712       84.187765
# 604                  -2.130953           0.033972    2.8081       46.676856
# 605                  -2.329400           0.392319    1.5871       26.117862
#
#      atom_mass_std  Z_mean      Z_std  group_mean  group_std  row_mean  \
# 0        55.471371    25.6  21.284736        15.2   1.469694       3.5
# 1        46.850826    36.4  17.984438        15.2   1.469694       4.1
# 2        39.927367    22.0  16.637307        16.0   1.788854       3.0
# 3        26.896304    18.6  10.846197        15.8   1.661325       3.1
# 4         6.480921    15.4   3.039737        16.2   1.249000       2.9
# ..             ...     ...        ...         ...        ...       ...
# 601      76.247122    30.2  29.721373        14.2   3.815757       3.4
# 602      45.033401    35.4  17.135927        14.2   3.841875       4.1
# 603      64.373975    36.1  24.780839        10.8   6.368673       4.2
# 604      57.391159    20.6  22.481993        15.0   1.549193       2.9
# 605      22.581586    12.4   9.656086        14.4   3.527038       2.5
#
#       row_std  mendeleev_no_mean  mendeleev_no_std  iupac_ordering_mean  \
# 0    1.024695               90.2          6.823489                 91.5
# 1    0.830662               89.6          6.499231                 90.9
# 2    1.264911               95.7          9.602604                 96.2
# 3    0.700000               93.8          8.435639                 94.6
# 4    0.300000               96.2          5.775812                 96.9
# ..        ...                ...               ...                  ...
# 601  1.743560               88.3         22.481326                 88.2
# 602  0.830662               84.1         20.186382                 87.5
# 603  1.469694               65.3         35.341336                 72.7
# 604  1.300000               93.5         10.022475                 91.1
# 605  0.921954               93.0         15.303594                 89.9
#
#      iupac_ordering_std  average_ionic_radius_mean  average_ionic_radius_std  \
# 0              7.256032                   0.850167                  0.166023
# 1              6.891299                   0.930167                  0.191321
# 2              9.260670                   0.817333                  0.150082
# 3              9.013323                   0.812000                  0.156432
# 4              6.503076                   0.774500                  0.072954
# ..                  ...                        ...                       ...
# 601           14.688771                   1.167500                  0.136217
# 602           14.214429                   0.955250                  0.223203
# 603           28.677692                   0.963900                  0.104039
# 604            8.263776                   1.090500                  0.235844
# 605           13.531075                   0.982000                  0.362899
#
#      atomic_radius_mean  atomic_radius_std  atomic_radius_calculated_mean  \
# 0                 1.120           0.240000                          1.032
# 1                 1.210           0.203470                          1.122
# 2                 0.835           0.428398                          0.756
# 3                 1.055           0.213834                          0.903
# 4                 0.990           0.135647                          0.824
# ..                  ...                ...                            ...
# 601               1.045           0.553376                          0.941
# 602               1.260           0.301496                          1.182
# 603               1.310           0.380657                          1.447
# 604               0.890           0.380000                          0.813
# 605               0.785           0.298371                          0.757
#
#      atomic_radius_calculated_std  van_der_waals_radius_mean  \
# 0                        0.261603                      1.858
# 1                        0.215583                      1.918
# 2                        0.442294                      1.679
# 3                        0.266122                      1.787
# 4                        0.144790                      1.749
# ..                            ...                        ...
# 601                      0.594482                      1.754
# 602                      0.352556                      1.928
# 603                      0.697453                      2.003
# 604                      0.425536                      1.701
# 605                      0.475942                      1.665
#
#      van_der_waals_radius_std  X_mean     X_std  electron_affinity_mean  \
# 0                    0.116344   2.381  0.253829                1.620268
# 1                    0.094742   2.363  0.239752                1.586368
# 2                    0.262810   3.296  0.856659                2.680022
# 3                    0.152253   2.758  0.686102                2.511520
# 4                    0.072863   2.877  0.478415                2.619340
# ..                        ...     ...       ...                     ...
# 601                  0.297328   2.857  0.769793                1.083881
# 602                  0.138622   2.252  0.447768                1.424819
# 603                  0.251239   2.003  0.707362                1.254716
# 604                  0.230974   2.815  0.779798                0.921565
# 605                  0.219784   2.890  0.731040                1.195531
#
#      electron_affinity_std  ionization_energy_mean  ionization_energy_std  \
# 0                 0.577758                9.799518               1.187119
# 1                 0.550996                9.434947               1.043638
# 2                 0.924540               14.022633               4.203661
# 3                 1.377665               11.073931               3.060735
# 4                 1.360966               11.904572               2.312979
# ..                     ...                     ...                    ...
# 601               0.500956               11.136734               3.085662
# 602               0.742304                9.181327               1.536030
# 603               1.007771                8.607763               2.155631
# 604               0.808119               11.826893               2.313133
# 605               0.375728               12.057612               2.227003
#
#      valence_mean  valence_std  density_of_solid_mean  density_of_solid_std  \
# 0             6.2     1.661325            3567.600000           3287.963814
# 1             6.2     1.661325            5283.000000           2693.897437
# 2             7.0     1.483240            3700.271600           2857.965168
# 3             5.8     1.661325            2586.382684           1640.412561
# 4             6.2     1.249000            1988.667066            378.570145
# ..            ...          ...                    ...                   ...
# 601           5.2     1.077033            3937.874654           4148.102874
# 602           5.2     1.166190            4888.200000           2597.296972
# 603           7.7     3.522783            4009.100000           2566.315898
# 604           5.0     1.549193            3141.274654           3276.449510
# 605           5.4     0.800000            1795.374654           1644.436559
#
#      molar_volume_mean  molar_volume_std  fusion_heat_mean  fusion_heat_std  \
# 0               15.880          2.535571             3.535         4.006468
# 1               16.414          2.499085             5.935         2.971159
# 2               12.850          2.774830             4.555         6.283272
# 3               15.799          2.917572             6.747         2.694662
# 4               15.894          2.323223             5.239         3.019339
# ..                 ...               ...               ...              ...
# 601             17.875          0.775052             4.376         6.250040
# 602             16.966          1.017371             5.221         2.344254
# 603             18.267          3.719191             3.644         3.856795
# 604             16.081          3.658411             3.071         3.743636
# 605             15.751          3.621918            14.386        34.643660
#
#      evaporation_heat_mean  evaporation_heat_std  specific_heat_mean  \
# 0                   58.870             80.694251              0.6143
# 1                   88.390             65.090329              0.3821
# 2                   60.794             85.495939              0.6028
# 3                   99.348            123.647600              0.5813
# 4                   43.314             80.438069              0.6227
# ..                     ...                   ...                 ...
# 601                 95.872            120.159224              0.6273
# 602                 98.720             94.842499              0.3891
# 603                100.300            120.359711              0.4924
# 604                 49.232             58.705448              0.7175
# 605                142.252            252.110460              0.8033
#
#      specific_heat_std
# 0             0.220629
# 1             0.202749
# 2             0.272825
# 3             0.223835
# 4             0.196934
# ..                 ...
# 601           0.358712
# 602           0.198097
# 603           0.264241
# 604           0.285590
# 605           0.191343
#
# [606 rows x 44 columns]

# %%
elmt = Element("Fe")
#elmt.density_of_solid # in gramm/liter !!!
elmt.atomic_mass/elmt.molar_volume * 1000
# Out:
# 7876.586741889985

# %%
elemental_properties
# Out:
# {'Ag': {'atomic_mass': 107.8682,
#   'Z': 47,
#   'group': 11,
#   'fusion_heat': 11.95,
#   'evaporation_heat': 254.1,
#   'specific_heat': 0.235,
#   'row': 5,
#   'mendeleev_no': 71.0,
#   'iupac_ordering': 72,
#   'average_ionic_radius': 1.0866666666666667,
#   'atomic_radius': 1.6,
#   'atomic_radius_calculated': 1.65,
#   'van_der_waals_radius': 2.11,
#   'X': 1.93,
#   'electron_affinity': 1.304473,
#   'ionization_energy': 7.576234,
#   'valence': 11,
#   'density_of_solid': 10490.0,
#   'molar_volume': 10.27,
#   'boiling_point': 2435.15,
#   'melting_point': 1234.93,
#   'thermal_conductivity': 430.0},
#  'Bi': {'atomic_mass': 208.9804,
#   'Z': 83,
#   'group': 15,
#   'fusion_heat': 11.0,
#   'evaporation_heat': 172.0,
#   'specific_heat': 0.122,
#   'row': 6,
#   'mendeleev_no': 87.0,
#   'iupac_ordering': 87,
#   'average_ionic_radius': 1.035,
#   'atomic_radius': 1.6,
#   'atomic_radius_calculated': 1.43,
#   'van_der_waals_radius': 2.07,
#   'X': 2.02,
#   'electron_affinity': 0.94236213,
#   'ionization_energy': 7.285516,
#   'valence': 5,
#   'density_of_solid': 9780.0,
#   'molar_volume': 21.31,
#   'boiling_point': 1837.15,
#   'melting_point': 544.4,
#   'thermal_conductivity': 8.0},
#  'P': {'atomic_mass': 30.973762,
#   'Z': 15,
#   'group': 15,
#   'fusion_heat': 2.51,
#   'evaporation_heat': 49.8,
#   'specific_heat': 0.769,
#   'row': 3,
#   'mendeleev_no': 90.0,
#   'iupac_ordering': 90,
#   'average_ionic_radius': 0.55,
#   'atomic_radius': 1.0,
#   'atomic_radius_calculated': 0.98,
#   'van_der_waals_radius': 1.8,
#   'X': 2.19,
#   'electron_affinity': 0.74660911,
#   'ionization_energy': 10.486686,
#   'valence': 5,
#   'density_of_solid': 1823.0,
#   'molar_volume': 17.02,
#   'boiling_point': 550,
#   'melting_point': 317.3,
#   'thermal_conductivity': 0.236},
#  'S': {'atomic_mass': 32.065,
#   'Z': 16,
#   'group': 16,
#   'fusion_heat': 1.23,
#   'evaporation_heat': 10.5,
#   'specific_heat': 0.708,
#   'row': 3,
#   'mendeleev_no': 94.0,
#   'iupac_ordering': 96,
#   'average_ionic_radius': 0.88,
#   'atomic_radius': 1.0,
#   'atomic_radius_calculated': 0.88,
#   'van_der_waals_radius': 1.8,
#   'X': 2.58,
#   'electron_affinity': 2.07710426,
#   'ionization_energy': 10.36001,
#   'valence': 6,
#   'density_of_solid': 1960.0,
#   'molar_volume': 15.53,
#   'boiling_point': 717.76,
#   'melting_point': 388.36,
#   'thermal_conductivity': 0.205},
#  'Se': {'atomic_mass': 78.96,
#   'Z': 34,
#   'group': 16,
#   'fusion_heat': 5.23,
#   'evaporation_heat': 59.7,
#   'specific_heat': 0.321,
#   'row': 4,
#   'mendeleev_no': 93.0,
#   'iupac_ordering': 95,
#   'average_ionic_radius': 1.0133333333333334,
#   'atomic_radius': 1.15,
#   'atomic_radius_calculated': 1.03,
#   'van_der_waals_radius': 1.9,
#   'X': 2.55,
#   'electron_affinity': 2.020604712,
#   'ionization_energy': 9.752392,
#   'valence': 6,
#   'density_of_solid': 4819.0,
#   'molar_volume': 16.42,
#   'boiling_point': 958.15,
#   'melting_point': 494.0,
#   'thermal_conductivity': 0.52},
#  'F': {'atomic_mass': 18.9984032,
#   'Z': 9,
#   'group': 17,
#   'fusion_heat': 0.51,
#   'evaporation_heat': 6.54,
#   'specific_heat': 0.824,
#   'row': 2,
#   'mendeleev_no': 102.0,
#   'iupac_ordering': 102,
#   'average_ionic_radius': 0.705,
#   'atomic_radius': 0.5,
#   'atomic_radius_calculated': 0.42,
#   'van_der_waals_radius': 1.47,
#   'X': 3.98,
#   'electron_affinity': 3.401189824,
#   'ionization_energy': 17.42282,
#   'valence': 7,
#   'density_of_solid': 1696.286,
#   'molar_volume': 11.2,
#   'boiling_point': 85.03999999999996,
#   'melting_point': 53.53,
#   'thermal_conductivity': 0.0277},
#  'Sb': {'atomic_mass': 121.76,
#   'Z': 51,
#   'group': 15,
#   'fusion_heat': 20.08,
#   'evaporation_heat': 195.2,
#   'specific_heat': 0.207,
#   'row': 5,
#   'mendeleev_no': 88.0,
#   'iupac_ordering': 88,
#   'average_ionic_radius': 0.8300000000000001,
#   'atomic_radius': 1.45,
#   'atomic_radius_calculated': 1.33,
#   'van_der_waals_radius': 2.06,
#   'X': 2.05,
#   'electron_affinity': 1.04740119,
#   'ionization_energy': 8.608389,
#   'valence': 5,
#   'density_of_solid': 6697.0,
#   'molar_volume': 18.19,
#   'boiling_point': 1860.15,
#   'melting_point': 903.78,
#   'thermal_conductivity': 24.0},
#  'Al': {'atomic_mass': 26.9815386,
#   'Z': 13,
#   'group': 13,
#   'fusion_heat': 10.75,
#   'evaporation_heat': 284.1,
#   'specific_heat': 0.897,
#   'row': 3,
#   'mendeleev_no': 80.0,
#   'iupac_ordering': 80,
#   'average_ionic_radius': 0.675,
#   'atomic_radius': 1.25,
#   'atomic_radius_calculated': 1.18,
#   'van_der_waals_radius': 1.84,
#   'X': 1.61,
#   'electron_affinity': 0.432835,
#   'ionization_energy': 5.985769,
#   'valence': 3,
#   'density_of_solid': 2700.0,
#   'molar_volume': 10.0,
#   'boiling_point': 2792.15,
#   'melting_point': 933.47,
#   'thermal_conductivity': 235.0},
#  'Cl': {'atomic_mass': 35.453,
#   'Z': 17,
#   'group': 17,
#   'fusion_heat': 6.41,
#   'evaporation_heat': 20.41,
#   'specific_heat': 0.479,
#   'row': 3,
#   'mendeleev_no': 99.0,
#   'iupac_ordering': 101,
#   'average_ionic_radius': 0.7799999999999999,
#   'atomic_radius': 1.0,
#   'atomic_radius_calculated': 0.79,
#   'van_der_waals_radius': 1.75,
#   'X': 3.16,
#   'electron_affinity': 3.61272528,
#   'ionization_energy': 12.967633,
#   'valence': 7,
#   'density_of_solid': 2038.70040253019,
#   'molar_volume': 17.39,
#   'boiling_point': 239.10999999999999,
#   'melting_point': 171.6,
#   'thermal_conductivity': 0.0089},
#  'O': {'atomic_mass': 15.9994,
#   'Z': 8,
#   'group': 16,
#   'fusion_heat': 0.44,
#   'evaporation_heat': 6.82,
#   'specific_heat': 0.918,
#   'row': 2,
#   'mendeleev_no': 101.0,
#   'iupac_ordering': 97,
#   'average_ionic_radius': 1.26,
#   'atomic_radius': 0.6,
#   'atomic_radius_calculated': 0.48,
#   'van_der_waals_radius': 1.52,
#   'X': 3.44,
#   'electron_affinity': 1.461112979,
#   'ionization_energy': 13.618055,
#   'valence': 6,
#   'density_of_solid': 921.6244239631336,
#   'molar_volume': 17.36,
#   'boiling_point': 90.18799999999999,
#   'melting_point': 54.8,
#   'thermal_conductivity': 0.02658},
#  'Sn': {'atomic_mass': 118.71,
#   'Z': 50,
#   'group': 14,
#   'fusion_heat': 7.07,
#   'evaporation_heat': 296.0,
#   'specific_heat': 0.227,
#   'row': 5,
#   'mendeleev_no': 83.0,
#   'iupac_ordering': 83,
#   'average_ionic_radius': 0.83,
#   'atomic_radius': 1.45,
#   'atomic_radius_calculated': 1.45,
#   'van_der_waals_radius': 2.17,
#   'X': 1.96,
#   'electron_affinity': 1.1120702,
#   'ionization_energy': 7.343918,
#   'valence': 4,
#   'density_of_solid': 7310.0,
#   'molar_volume': 16.29,
#   'boiling_point': 2859.15,
#   'melting_point': 505.08,
#   'thermal_conductivity': 67.0},
#  'N': {'atomic_mass': 14.0067,
#   'Z': 7,
#   'group': 15,
#   'fusion_heat': 0.72,
#   'evaporation_heat': 5.58,
#   'specific_heat': 1.04,
#   'row': 2,
#   'mendeleev_no': 100.0,
#   'iupac_ordering': 91,
#   'average_ionic_radius': 0.63,
#   'atomic_radius': 0.65,
#   'atomic_radius_calculated': 0.56,
#   'van_der_waals_radius': 1.55,
#   'X': 3.04,
#   'electron_affinity': -0.07,
#   'ionization_energy': 14.53413,
#   'valence': 5,
#   'density_of_solid': 1034.4682422451995,
#   'molar_volume': 13.54,
#   'boiling_point': 77.35499999999999,
#   'melting_point': 63.05,
#   'thermal_conductivity': 0.02583},
#  'As': {'atomic_mass': 74.9216,
#   'Z': 33,
#   'group': 15,
#   'fusion_heat': 24.44,
#   'evaporation_heat': 32.4,
#   'specific_heat': 0.329,
#   'row': 4,
#   'mendeleev_no': 89.0,
#   'iupac_ordering': 89,
#   'average_ionic_radius': 0.6599999999999999,
#   'atomic_radius': 1.15,
#   'atomic_radius_calculated': 1.14,
#   'van_der_waals_radius': 1.85,
#   'X': 2.18,
#   'electron_affinity': 0.8044863,
#   'ionization_energy': 9.78855,
#   'valence': 5,
#   'density_of_solid': 5727.0,
#   'molar_volume': 12.95,
#   'boiling_point': 889.15,
#   'melting_point': 1090.0,
#   'thermal_conductivity': 50.0},
#  'H': {'atomic_mass': 1.00794,
#   'Z': 1,
#   'group': 1,
#   'fusion_heat': 0.117,
#   'evaporation_heat': 0.904,
#   'specific_heat': 14.304,
#   'row': 1,
#   'mendeleev_no': 103.0,
#   'iupac_ordering': 92,
#   'average_ionic_radius': 0.0,
#   'atomic_radius': 0.25,
#   'atomic_radius_calculated': 0.53,
#   'van_der_waals_radius': 1.1,
#   'X': 2.2,
#   'electron_affinity': 0.75419519,
#   'ionization_energy': 13.598434599702,
#   'valence': 1,
#   'density_of_solid': 88.26094570928197,
#   'molar_volume': 11.42,
#   'boiling_point': 20.270999999999987,
#   'melting_point': 14.01,
#   'thermal_conductivity': 0.1805},
#  'I': {'atomic_mass': 126.90447,
#   'Z': 53,
#   'group': 17,
#   'fusion_heat': 15.52,
#   'evaporation_heat': 41.95,
#   'specific_heat': 0.214,
#   'row': 5,
#   'mendeleev_no': 97.0,
#   'iupac_ordering': 99,
#   'average_ionic_radius': 1.2733333333333334,
#   'atomic_radius': 1.4,
#   'atomic_radius_calculated': 1.15,
#   'van_der_waals_radius': 1.98,
#   'X': 2.66,
#   'electron_affinity': 3.059046537,
#   'ionization_energy': 10.45126,
#   'valence': 7,
#   'density_of_solid': 4940.0,
#   'molar_volume': 25.72,
#   'boiling_point': 457.54999999999995,
#   'melting_point': 386.85,
#   'thermal_conductivity': 0.449},
#  'Ba': {'atomic_mass': 137.327,
#   'Z': 56,
#   'group': 2,
#   'fusion_heat': 7.66,
#   'evaporation_heat': 142.0,
#   'specific_heat': 0.204,
#   'row': 6,
#   'mendeleev_no': 14.0,
#   'iupac_ordering': 13,
#   'average_ionic_radius': 1.49,
#   'atomic_radius': 2.15,
#   'atomic_radius_calculated': 2.53,
#   'van_der_waals_radius': 2.68,
#   'X': 0.89,
#   'electron_affinity': 0.144626,
#   'ionization_energy': 5.2116646,
#   'valence': 2,
#   'density_of_solid': 3510.0,
#   'molar_volume': 38.16,
#   'boiling_point': 2118.15,
#   'melting_point': 1000.0,
#   'thermal_conductivity': 18.0},
#  'Ca': {'atomic_mass': 40.078,
#   'Z': 20,
#   'group': 2,
#   'fusion_heat': 9.2,
#   'evaporation_heat': 153.6,
#   'specific_heat': 0.647,
#   'row': 4,
#   'mendeleev_no': 16.0,
#   'iupac_ordering': 15,
#   'average_ionic_radius': 1.14,
#   'atomic_radius': 1.8,
#   'atomic_radius_calculated': 1.94,
#   'van_der_waals_radius': 2.31,
#   'X': 1,
#   'electron_affinity': 0.024551,
#   'ionization_energy': 6.11315547,
#   'valence': 2,
#   'density_of_solid': 1550.0,
#   'molar_volume': 26.2,
#   'boiling_point': 1757.15,
#   'melting_point': 1115.0,
#   'thermal_conductivity': 200.0},
#  'Mo': {'atomic_mass': 95.94,
#   'Z': 42,
#   'group': 6,
#   'fusion_heat': 28.0,
#   'evaporation_heat': 590.0,
#   'specific_heat': 0.251,
#   'row': 5,
#   'mendeleev_no': 56.0,
#   'iupac_ordering': 57,
#   'average_ionic_radius': 0.775,
#   'atomic_radius': 1.45,
#   'atomic_radius_calculated': 1.9,
#   'van_der_waals_radius': 2.17,
#   'X': 2.16,
#   'electron_affinity': 0.747238,
#   'ionization_energy': 7.09243,
#   'valence': 6,
#   'density_of_solid': 10280.0,
#   'molar_volume': 9.38,
#   'boiling_point': 4912.15,
#   'melting_point': 2896.0,
#   'thermal_conductivity': 139.0},
#  'Te': {'atomic_mass': 127.6,
#   'Z': 52,
#   'group': 16,
#   'fusion_heat': 17.91,
#   'evaporation_heat': 49.8,
#   'specific_heat': 0.202,
#   'row': 5,
#   'mendeleev_no': 92.0,
#   'iupac_ordering': 94,
#   'average_ionic_radius': 1.2933333333333332,
#   'atomic_radius': 1.4,
#   'atomic_radius_calculated': 1.23,
#   'van_der_waals_radius': 2.06,
#   'X': 2.1,
#   'electron_affinity': 1.9708757,
#   'ionization_energy': 9.009808,
#   'valence': 6,
#   'density_of_solid': 6240.0,
#   'molar_volume': 20.46,
#   'boiling_point': 1261.15,
#   'melting_point': 722.66,
#   'thermal_conductivity': 3.0},
#  'U': {'atomic_mass': 238.02891,
#   'Z': 92,
#   'group': 3,
#   'fusion_heat': 12.6,
#   'evaporation_heat': 417.0,
#   'specific_heat': 0.116,
#   'row': 7,
#   'mendeleev_no': 45.0,
#   'iupac_ordering': 29,
#   'average_ionic_radius': 0.9912500000000001,
#   'atomic_radius': 1.75,
#   'atomic_radius_calculated': 1.75,
#   'van_der_waals_radius': 2.41,
#   'X': 1.38,
#   'electron_affinity': 0.314979,
#   'ionization_energy': 6.19405,
#   'valence': 4,
#   'density_of_solid': 19050.0,
#   'molar_volume': 12.49,
#   'boiling_point': 4404.15,
#   'melting_point': 1405.3,
#   'thermal_conductivity': 27.0},
#  'W': {'atomic_mass': 183.84,
#   'Z': 74,
#   'group': 6,
#   'fusion_heat': 35.0,
#   'evaporation_heat': 824.0,
#   'specific_heat': 0.132,
#   'row': 6,
#   'mendeleev_no': 55.0,
#   'iupac_ordering': 56,
#   'average_ionic_radius': 0.7666666666666666,
#   'atomic_radius': 1.35,
#   'atomic_radius_calculated': 1.93,
#   'van_der_waals_radius': 2.18,
#   'X': 2.36,
#   'electron_affinity': 0.81650082,
#   'ionization_energy': 7.86403,
#   'valence': 6,
#   'density_of_solid': 19250.0,
#   'molar_volume': 9.47,
#   'boiling_point': 5828.15,
#   'melting_point': 3695.0,
#   'thermal_conductivity': 170.0},
#  'Ce': {'atomic_mass': 140.116,
#   'Z': 58,
#   'group': 3,
#   'fusion_heat': 5.2,
#   'evaporation_heat': 398.0,
#   'specific_heat': 0.192,
#   'row': 6,
#   'mendeleev_no': 32.0,
#   'iupac_ordering': 46,
#   'average_ionic_radius': 1.08,
#   'atomic_radius': 1.85,
#   'atomic_radius_calculated': 1.85,
#   'van_der_waals_radius': 2.42,
#   'X': 1.12,
#   'electron_affinity': 0.60016027,
#   'ionization_energy': 5.5386,
#   'valence': 4,
#   'density_of_solid': 6689.0,
#   'molar_volume': 20.69,
#   'boiling_point': 3716.15,
#   'melting_point': 1068.0,
#   'thermal_conductivity': 11.0},
#  'Pt': {'atomic_mass': 195.084,
#   'Z': 78,
#   'group': 10,
#   'fusion_heat': 21.76,
#   'evaporation_heat': 470.0,
#   'specific_heat': 0.133,
#   'row': 6,
#   'mendeleev_no': 68.0,
#   'iupac_ordering': 68,
#   'average_ionic_radius': 0.805,
#   'atomic_radius': 1.35,
#   'atomic_radius_calculated': 1.77,
#   'van_der_waals_radius': 2.13,
#   'X': 2.28,
#   'electron_affinity': 2.125105,
#   'ionization_energy': 8.95883,
#   'valence': 10,
#   'density_of_solid': 21090.0,
#   'molar_volume': 9.09,
#   'boiling_point': 4098.15,
#   'melting_point': 2041.4,
#   'thermal_conductivity': 72.0},
#  'Co': {'atomic_mass': 58.933195,
#   'Z': 27,
#   'group': 9,
#   'fusion_heat': 15.48,
#   'evaporation_heat': 389.1,
#   'specific_heat': 0.421,
#   'row': 4,
#   'mendeleev_no': 64.0,
#   'iupac_ordering': 67,
#   'average_ionic_radius': 0.7683333333333334,
#   'atomic_radius': 1.35,
#   'atomic_radius_calculated': 1.52,
#   'van_der_waals_radius': 2.0,
#   'X': 1.88,
#   'electron_affinity': 0.66225547,
#   'ionization_energy': 7.88101,
#   'valence': 9,
#   'density_of_solid': 8900.0,
#   'molar_volume': 6.67,
#   'boiling_point': 3200.15,
#   'melting_point': 1768.0,
#   'thermal_conductivity': 100.0},
#  'Re': {'atomic_mass': 186.207,
#   'Z': 75,
#   'group': 7,
#   'fusion_heat': 34.0,
#   'evaporation_heat': 704.0,
#   'specific_heat': 0.137,
#   'row': 6,
#   'mendeleev_no': 58.0,
#   'iupac_ordering': 59,
#   'average_ionic_radius': 0.7124999999999999,
#   'atomic_radius': 1.35,
#   'atomic_radius_calculated': 1.88,
#   'van_der_waals_radius': 2.16,
#   'X': 1.9,
#   'electron_affinity': 0.06039664,
#   'ionization_energy': 7.83352,
#   'valence': 7,
#   'density_of_solid': 21020.0,
#   'molar_volume': 8.86,
#   'boiling_point': 5863.15,
#   'melting_point': 3459.0,
#   'thermal_conductivity': 48.0},
#  'Dy': {'atomic_mass': 162.5,
#   'Z': 66,
#   'group': 3,
#   'fusion_heat': 11.06,
#   'evaporation_heat': 291.0,
#   'specific_heat': 0.173,
#   'row': 6,
#   'mendeleev_no': 24.0,
#   'iupac_ordering': 38,
#   'average_ionic_radius': 1.131,
#   'atomic_radius': 1.75,
#   'atomic_radius_calculated': 2.28,
#   'van_der_waals_radius': 2.31,
#   'X': 1.22,
#   'electron_affinity': 0.0153,
#   'ionization_energy': 5.93905,
#   'valence': 10,
#   'density_of_solid': 8551.0,
#   'molar_volume': 19.01,
#   'boiling_point': 2840.15,
#   'melting_point': 1680.0,
#   'thermal_conductivity': 11.0},
#  'Nb': {'atomic_mass': 92.90638,
#   'Z': 41,
#   'group': 5,
#   'fusion_heat': 26.8,
#   'evaporation_heat': 680.0,
#   'specific_heat': 0.265,
#   'row': 5,
#   'mendeleev_no': 53.0,
#   'iupac_ordering': 54,
#   'average_ionic_radius': 0.82,
#   'atomic_radius': 1.45,
#   'atomic_radius_calculated': 1.98,
#   'van_der_waals_radius': 2.18,
#   'X': 1.6,
#   'electron_affinity': 0.917407,
#   'ionization_energy': 6.75885,
#   'valence': 5,
#   'density_of_solid': 8570.0,
#   'molar_volume': 10.83,
#   'boiling_point': 5014.15,
#   'melting_point': 2750.0,
#   'thermal_conductivity': 54.0},
#  'Er': {'atomic_mass': 167.259,
#   'Z': 68,
#   'group': 3,
#   'fusion_heat': 19.9,
#   'evaporation_heat': 317.0,
#   'specific_heat': 0.168,
#   'row': 6,
#   'mendeleev_no': 22.0,
#   'iupac_ordering': 36,
#   'average_ionic_radius': 1.03,
#   'atomic_radius': 1.75,
#   'atomic_radius_calculated': 2.26,
#   'van_der_waals_radius': 2.29,
#   'X': 1.24,
#   'electron_affinity': 0.312,
#   'ionization_energy': 6.1077,
#   'valence': 12,
#   'density_of_solid': 9066.0,
#   'molar_volume': 18.46,
#   'boiling_point': 3141.15,
#   'melting_point': 1802.0,
#   'thermal_conductivity': 15.0},
#  'Ru': {'atomic_mass': 101.07,
#   'Z': 44,
#   'group': 8,
#   'fusion_heat': 25.5,
#   'evaporation_heat': 619,
#   'specific_heat': 0.238,
#   'row': 5,
#   'mendeleev_no': 62.0,
#   'iupac_ordering': 63,
#   'average_ionic_radius': 0.661,
#   'atomic_radius': 1.3,
#   'atomic_radius_calculated': 1.78,
#   'van_der_waals_radius': 2.13,
#   'X': 2.2,
#   'electron_affinity': 1.046272,
#   'ionization_energy': 7.3605,
#   'valence': 8,
#   'density_of_solid': 12370.0,
#   'molar_volume': 8.17,
#   'boiling_point': 4420.15,
#   'melting_point': 2607.0,
#   'thermal_conductivity': 120.0},
#  'Gd': {'atomic_mass': 157.25,
#   'Z': 64,
#   'group': 3,
#   'fusion_heat': 10.05,
#   'evaporation_heat': 398.0,
#   'specific_heat': 0.236,
#   'row': 6,
#   'mendeleev_no': 27.0,
#   'iupac_ordering': 40,
#   'average_ionic_radius': 1.075,
#   'atomic_radius': 1.8,
#   'atomic_radius_calculated': 2.33,
#   'van_der_waals_radius': 2.34,
#   'X': 1.2,
#   'electron_affinity': 0.2123,
#   'ionization_energy': 6.1498,
#   'valence': 8,
#   'density_of_solid': 7901.0,
#   'molar_volume': 19.9,
#   'boiling_point': 3546.15,
#   'melting_point': 1585.0,
#   'thermal_conductivity': 11.0},
#  'Ho': {'atomic_mass': 164.93032,
#   'Z': 67,
#   'group': 3,
#   'fusion_heat': 17.0,
#   'evaporation_heat': 301.0,
#   'specific_heat': 0.165,
#   'row': 6,
#   'mendeleev_no': 23.0,
#   'iupac_ordering': 37,
#   'average_ionic_radius': 1.041,
#   'atomic_radius': 1.75,
#   'atomic_radius_calculated': 1.75,
#   'van_der_waals_radius': 2.3,
#   'X': 1.23,
#   'electron_affinity': 0.338,
#   'ionization_energy': 6.0215,
#   'valence': 11,
#   'density_of_solid': 8795.0,
#   'molar_volume': 18.74,
#   'boiling_point': 2973.15,
#   'melting_point': 1734.0,
#   'thermal_conductivity': 16.0},
#  'Ta': {'atomic_mass': 180.94788,
#   'Z': 73,
#   'group': 5,
#   'fusion_heat': 24.7,
#   'evaporation_heat': 758.0,
#   'specific_heat': 0.14,
#   'row': 6,
#   'mendeleev_no': 52.0,
#   'iupac_ordering': 53,
#   'average_ionic_radius': 0.82,
#   'atomic_radius': 1.45,
#   'atomic_radius_calculated': 2.0,
#   'van_der_waals_radius': 2.22,
#   'X': 1.5,
#   'electron_affinity': 0.32885923,
#   'ionization_energy': 7.549571,
#   'valence': 5,
#   'density_of_solid': 16650.0,
#   'molar_volume': 10.85,
#   'boiling_point': 5728.15,
#   'melting_point': 3290.0,
#   'thermal_conductivity': 57.0},
#  'In': {'atomic_mass': 114.818,
#   'Z': 49,
#   'group': 13,
#   'fusion_heat': 3.24,
#   'evaporation_heat': 225.1,
#   'specific_heat': 0.233,
#   'row': 5,
#   'mendeleev_no': 79.0,
#   'iupac_ordering': 78,
#   'average_ionic_radius': 0.94,
#   'atomic_radius': 1.55,
#   'atomic_radius_calculated': 1.56,
#   'van_der_waals_radius': 1.93,
#   'X': 1.78,
#   'electron_affinity': 0.299,
#   'ionization_energy': 5.7863557,
#   'valence': 3,
#   'density_of_solid': 7310.0,
#   'molar_volume': 15.76,
#   'boiling_point': 2300.15,
#   'melting_point': 429.75,
#   'thermal_conductivity': 82.0},
#  'La': {'atomic_mass': 138.90547,
#   'Z': 57,
#   'group': 3,
#   'fusion_heat': 8.5,
#   'evaporation_heat': 402.0,
#   'specific_heat': 0.195,
#   'row': 6,
#   'mendeleev_no': 33.0,
#   'iupac_ordering': 47,
#   'average_ionic_radius': 1.172,
#   'atomic_radius': 1.95,
#   'atomic_radius_calculated': 1.95,
#   'van_der_waals_radius': 2.43,
#   'X': 1.1,
#   'electron_affinity': 0.5575462,
#   'ionization_energy': 5.5769,
#   'valence': 3,
#   'density_of_solid': 6146.0,
#   'molar_volume': 22.39,
#   'boiling_point': 3737.15,
#   'melting_point': 1193.0,
#   'thermal_conductivity': 13.0},
#  'Li': {'atomic_mass': 6.941,
#   'Z': 3,
#   'group': 1,
#   'fusion_heat': 2.89,
#   'evaporation_heat': 148.0,
#   'specific_heat': 3.582,
#   'row': 2,
#   'mendeleev_no': 12.0,
#   'iupac_ordering': 11,
#   'average_ionic_radius': 0.9,
#   'atomic_radius': 1.45,
#   'atomic_radius_calculated': 1.67,
#   'van_der_waals_radius': 1.82,
#   'X': 0.98,
#   'electron_affinity': 0.61804922,
#   'ionization_energy': 5.391714996,
#   'valence': 1,
#   'density_of_solid': 535.0,
#   'molar_volume': 13.02,
#   'boiling_point': 1615.15,
#   'melting_point': 453.69,
#   'thermal_conductivity': 85.0},
#  'Lu': {'atomic_mass': 174.967,
#   'Z': 71,
#   'group': 3,
#   'fusion_heat': 22,
#   'evaporation_heat': 414.0,
#   'specific_heat': 0.154,
#   'row': 6,
#   'mendeleev_no': 20.0,
#   'iupac_ordering': 33,
#   'average_ionic_radius': 1.001,
#   'atomic_radius': 1.75,
#   'atomic_radius_calculated': 2.17,
#   'van_der_waals_radius': 2.24,
#   'X': 1.27,
#   'electron_affinity': 0.23887,
#   'ionization_energy': 5.425871,
#   'valence': 15,
#   'density_of_solid': 9841.0,
#   'molar_volume': 17.78,
#   'boiling_point': 3675.15,
#   'melting_point': 1925.0,
#   'thermal_conductivity': 16.0},
#  'Mg': {'atomic_mass': 24.305,
#   'Z': 12,
#   'group': 2,
#   'fusion_heat': 9.2,
#   'evaporation_heat': 131.8,
#   'specific_heat': 1.023,
#   'row': 3,
#   'mendeleev_no': 73.0,
#   'iupac_ordering': 16,
#   'average_ionic_radius': 0.86,
#   'atomic_radius': 1.5,
#   'atomic_radius_calculated': 1.45,
#   'van_der_waals_radius': 1.73,
#   'X': 1.31,
#   'electron_affinity': -0.42,
#   'ionization_energy': 7.646236,
#   'valence': 2,
#   'density_of_solid': 1738.0,
#   'molar_volume': 14.0,
#   'boiling_point': 1363.15,
#   'melting_point': 923.0,
#   'thermal_conductivity': 160.0},
#  'Mn': {'atomic_mass': 54.938045,
#   'Z': 25,
#   'group': 7,
#   'fusion_heat': 13.4,
#   'evaporation_heat': 221.0,
#   'specific_heat': 0.479,
#   'row': 4,
#   'mendeleev_no': 60.0,
#   'iupac_ordering': 61,
#   'average_ionic_radius': 0.8775,
#   'atomic_radius': 1.4,
#   'atomic_radius_calculated': 1.61,
#   'van_der_waals_radius': 2.05,
#   'X': 1.55,
#   'electron_affinity': -0.52,
#   'ionization_energy': 7.434038,
#   'valence': 7,
#   'density_of_solid': 7470.0,
#   'molar_volume': 7.35,
#   'boiling_point': 2334.15,
#   'melting_point': 1519.0,
#   'thermal_conductivity': 7.8},
#  'Na': {'atomic_mass': 22.98976928,
#   'Z': 11,
#   'group': 1,
#   'fusion_heat': 2.64,
#   'evaporation_heat': 97.9,
#   'specific_heat': 1.228,
#   'row': 3,
#   'mendeleev_no': 11.0,
#   'iupac_ordering': 10,
#   'average_ionic_radius': 1.16,
#   'atomic_radius': 1.8,
#   'atomic_radius_calculated': 1.9,
#   'van_der_waals_radius': 2.27,
#   'X': 0.93,
#   'electron_affinity': 0.54792625,
#   'ionization_energy': 5.13907696,
#   'valence': 1,
#   'density_of_solid': 968.0,
#   'molar_volume': 23.78,
#   'boiling_point': 1156.0900000000001,
#   'melting_point': 370.87,
#   'thermal_conductivity': 140.0},
#  'Cr': {'atomic_mass': 51.9961,
#   'Z': 24,
#   'group': 6,
#   'fusion_heat': 21.0,
#   'evaporation_heat': 342.0,
#   'specific_heat': 0.449,
#   'row': 4,
#   'mendeleev_no': 57.0,
#   'iupac_ordering': 58,
#   'average_ionic_radius': 0.94,
#   'atomic_radius': 1.4,
#   'atomic_radius_calculated': 1.66,
#   'van_der_waals_radius': 2.06,
#   'X': 1.66,
#   'electron_affinity': 0.67592827,
#   'ionization_energy': 6.76651,
#   'valence': 6,
#   'density_of_solid': 7140.0,
#   'molar_volume': 7.23,
#   'boiling_point': 2944.15,
#   'melting_point': 2180.0,
#   'thermal_conductivity': 94.0},
#  'Nd': {'atomic_mass': 144.242,
#   'Z': 60,
#   'group': 3,
#   'fusion_heat': 7.1,
#   'evaporation_heat': 289.0,
#   'specific_heat': 0.19,
#   'row': 6,
#   'mendeleev_no': 30.0,
#   'iupac_ordering': 44,
#   'average_ionic_radius': 1.2765,
#   'atomic_radius': 1.85,
#   'atomic_radius_calculated': 2.06,
#   'van_der_waals_radius': 2.39,
#   'X': 1.14,
#   'electron_affinity': 0.0974933,
#   'ionization_energy': 5.525,
#   'valence': 4,
#   'density_of_solid': 6800.0,
#   'molar_volume': 20.59,
#   'boiling_point': 3347.15,
#   'melting_point': 1297.0,
#   'thermal_conductivity': 17.0},
#  'Ni': {'atomic_mass': 58.6934,
#   'Z': 28,
#   'group': 10,
#   'fusion_heat': 17.61,
#   'evaporation_heat': 378.6,
#   'specific_heat': 0.444,
#   'row': 4,
#   'mendeleev_no': 67.0,
#   'iupac_ordering': 70,
#   'average_ionic_radius': 0.74,
#   'atomic_radius': 1.35,
#   'atomic_radius_calculated': 1.49,
#   'van_der_waals_radius': 1.97,
#   'X': 1.91,
#   'electron_affinity': 1.1571612,
#   'ionization_energy': 7.639878,
#   'valence': 10,
#   'density_of_solid': 8908.0,
#   'molar_volume': 6.59,
#   'boiling_point': 3186.15,
#   'melting_point': 1728.0,
#   'thermal_conductivity': 91.0},
#  'Pr': {'atomic_mass': 140.90765,
#   'Z': 59,
#   'group': 3,
#   'fusion_heat': 11.3,
#   'evaporation_heat': 331.0,
#   'specific_heat': 0.193,
#   'row': 6,
#   'mendeleev_no': 31.0,
#   'iupac_ordering': 45,
#   'average_ionic_radius': 1.06,
#   'atomic_radius': 1.85,
#   'atomic_radius_calculated': 2.47,
#   'van_der_waals_radius': 2.4,
#   'X': 1.13,
#   'electron_affinity': 0.1092346,
#   'ionization_energy': 5.4702,
#   'valence': 3,
#   'density_of_solid': 6640.0,
#   'molar_volume': 20.8,
#   'boiling_point': 3793.15,
#   'melting_point': 1208.0,
#   'thermal_conductivity': 13.0},
#  'Sm': {'atomic_mass': 150.36,
#   'Z': 62,
#   'group': 3,
#   'fusion_heat': 8.9,
#   'evaporation_heat': 165.0,
#   'specific_heat': 0.197,
#   'row': 6,
#   'mendeleev_no': 28.0,
#   'iupac_ordering': 42,
#   'average_ionic_radius': 1.229,
#   'atomic_radius': 1.85,
#   'atomic_radius_calculated': 2.38,
#   'van_der_waals_radius': 2.36,
#   'X': 1.17,
#   'electron_affinity': 0.162,
#   'ionization_energy': 5.64371,
#   'valence': 6,
#   'density_of_solid': 7353.0,
#   'molar_volume': 19.98,
#   'boiling_point': 2067.15,
#   'melting_point': 1345.0,
#   'thermal_conductivity': 13.0},
#  'Os': {'atomic_mass': 190.23,
#   'Z': 76,
#   'group': 8,
#   'fusion_heat': 31.7,
#   'evaporation_heat': 738.0,
#   'specific_heat': 0.13,
#   'row': 6,
#   'mendeleev_no': 63.0,
#   'iupac_ordering': 62,
#   'average_ionic_radius': 0.673,
#   'atomic_radius': 1.3,
#   'atomic_radius_calculated': 1.85,
#   'van_der_waals_radius': 2.16,
#   'X': 2.2,
#   'electron_affinity': 1.07766124,
#   'ionization_energy': 8.43823,
#   'valence': 8,
#   'density_of_solid': 22610.0,
#   'molar_volume': 8.42,
#   'boiling_point': 5281.15,
#   'melting_point': 3306.0,
#   'thermal_conductivity': 88.0},
#  'Sr': {'atomic_mass': 87.62,
#   'Z': 38,
#   'group': 2,
#   'fusion_heat': 9.2,
#   'evaporation_heat': 144.0,
#   'specific_heat': 0.306,
#   'row': 5,
#   'mendeleev_no': 15.0,
#   'iupac_ordering': 14,
#   'average_ionic_radius': 1.32,
#   'atomic_radius': 2.0,
#   'atomic_radius_calculated': 2.19,
#   'van_der_waals_radius': 2.49,
#   'X': 0.95,
#   'electron_affinity': 0.052066,
#   'ionization_energy': 5.69486745,
#   'valence': 2,
#   'density_of_solid': 2630.0,
#   'molar_volume': 33.94,
#   'boiling_point': 1650.15,
#   'melting_point': 1050.0,
#   'thermal_conductivity': 35.0},
#  'Tb': {'atomic_mass': 158.92535,
#   'Z': 65,
#   'group': 3,
#   'fusion_heat': 10.15,
#   'evaporation_heat': 389.0,
#   'specific_heat': 0.182,
#   'row': 6,
#   'mendeleev_no': 26.0,
#   'iupac_ordering': 39,
#   'average_ionic_radius': 0.9815,
#   'atomic_radius': 1.75,
#   'atomic_radius_calculated': 2.25,
#   'van_der_waals_radius': 2.33,
#   'X': 1.1,
#   'electron_affinity': 0.131318,
#   'ionization_energy': 5.8638,
#   'valence': 9,
#   'density_of_solid': 8219.0,
#   'molar_volume': 19.3,
#   'boiling_point': 3503.15,
#   'melting_point': 1629.0,
#   'thermal_conductivity': 11.0},
#  'Ti': {'atomic_mass': 47.867,
#   'Z': 22,
#   'group': 4,
#   'fusion_heat': 18.8,
#   'evaporation_heat': 422.6,
#   'specific_heat': 0.523,
#   'row': 4,
#   'mendeleev_no': 51.0,
#   'iupac_ordering': 52,
#   'average_ionic_radius': 0.8516666666666667,
#   'atomic_radius': 1.4,
#   'atomic_radius_calculated': 1.76,
#   'van_der_waals_radius': 2.11,
#   'X': 1.54,
#   'electron_affinity': 0.075545,
#   'ionization_energy': 6.82812,
#   'valence': 4,
#   'density_of_solid': 4507.0,
#   'molar_volume': 10.64,
#   'boiling_point': 3560.15,
#   'melting_point': 1941.0,
#   'thermal_conductivity': 22.0},
#  'Tm': {'atomic_mass': 168.93421,
#   'Z': 69,
#   'group': 3,
#   'fusion_heat': 16.84,
#   'evaporation_heat': 232.0,
#   'specific_heat': 0.16,
#   'row': 6,
#   'mendeleev_no': 21.0,
#   'iupac_ordering': 35,
#   'average_ionic_radius': 1.095,
#   'atomic_radius': 1.75,
#   'atomic_radius_calculated': 2.22,
#   'van_der_waals_radius': 2.27,
#   'X': 1.25,
#   'electron_affinity': 1.02922,
#   'ionization_energy': 6.18431,
#   'valence': 13,
#   'density_of_solid': 9321.0,
#   'molar_volume': 19.1,
#   'boiling_point': 2223.15,
#   'melting_point': 1818.0,
#   'thermal_conductivity': 17.0},
#  'Cd': {'atomic_mass': 112.411,
#   'Z': 48,
#   'group': 12,
#   'fusion_heat': 6.11,
#   'evaporation_heat': 59.1,
#   'specific_heat': 0.232,
#   'row': 5,
#   'mendeleev_no': 75.0,
#   'iupac_ordering': 75,
#   'average_ionic_radius': 1.09,
#   'atomic_radius': 1.55,
#   'atomic_radius_calculated': 1.61,
#   'van_der_waals_radius': 2.18,
#   'X': 1.69,
#   'electron_affinity': -0.72,
#   'ionization_energy': 8.99382,
#   'valence': 2,
#   'density_of_solid': 8650.0,
#   'molar_volume': 13.0,
#   'boiling_point': 1040.15,
#   'melting_point': 594.22,
#   'thermal_conductivity': 97.0},
#  'Cu': {'atomic_mass': 63.546,
#   'Z': 29,
#   'group': 11,
#   'fusion_heat': 13.01,
#   'evaporation_heat': 304.6,
#   'specific_heat': 0.385,
#   'row': 4,
#   'mendeleev_no': 72.0,
#   'iupac_ordering': 73,
#   'average_ionic_radius': 0.82,
#   'atomic_radius': 1.35,
#   'atomic_radius_calculated': 1.45,
#   'van_der_waals_radius': 1.96,
#   'X': 1.9,
#   'electron_affinity': 1.235784,
#   'ionization_energy': 7.72638,
#   'valence': 11,
#   'density_of_solid': 8920.0,
#   'molar_volume': 7.11,
#   'boiling_point': 2833.15,
#   'melting_point': 1357.77,
#   'thermal_conductivity': 400.0},
#  'Fe': {'atomic_mass': 55.845,
#   'Z': 26,
#   'group': 8,
#   'fusion_heat': 13.8,
#   'evaporation_heat': 340.0,
#   'specific_heat': 0.449,
#   'row': 4,
#   'mendeleev_no': 61.0,
#   'iupac_ordering': 64,
#   'average_ionic_radius': 0.8525,
#   'atomic_radius': 1.4,
#   'atomic_radius_calculated': 1.56,
#   'van_der_waals_radius': 2.04,
#   'X': 1.83,
#   'electron_affinity': 0.15323635,
#   'ionization_energy': 7.9024681,
#   'valence': 8,
#   'density_of_solid': 7874.0,
#   'molar_volume': 7.09,
#   'boiling_point': 3134.15,
#   'melting_point': 1811.0,
#   'thermal_conductivity': 80.0},
#  'Pb': {'atomic_mass': 207.2,
#   'Z': 82,
#   'group': 14,
#   'fusion_heat': 4.77,
#   'evaporation_heat': 177.8,
#   'specific_heat': 0.13,
#   'row': 6,
#   'mendeleev_no': 82.0,
#   'iupac_ordering': 82,
#   'average_ionic_radius': 1.1225,
#   'atomic_radius': 1.8,
#   'atomic_radius_calculated': 1.54,
#   'van_der_waals_radius': 2.02,
#   'X': 2.33,
#   'electron_affinity': 0.3567212,
#   'ionization_energy': 7.4166799,
#   'valence': 4,
#   'density_of_solid': 11340.0,
#   'molar_volume': 18.26,
#   'boiling_point': 2022.15,
#   'melting_point': 600.61,
#   'thermal_conductivity': 35.0},
#  'Zn': {'atomic_mass': 65.409,
#   'Z': 30,
#   'group': 12,
#   'fusion_heat': 7.28,
#   'evaporation_heat': 114.8,
#   'specific_heat': 0.388,
#   'row': 4,
#   'mendeleev_no': 76.0,
#   'iupac_ordering': 76,
#   'average_ionic_radius': 0.88,
#   'atomic_radius': 1.35,
#   'atomic_radius_calculated': 1.42,
#   'van_der_waals_radius': 2.01,
#   'X': 1.65,
#   'electron_affinity': -0.62,
#   'ionization_energy': 9.394197,
#   'valence': 2,
#   'density_of_solid': 7140.0,
#   'molar_volume': 9.16,
#   'boiling_point': 1180.15,
#   'melting_point': 692.68,
#   'thermal_conductivity': 120.0},
#  'Y': {'atomic_mass': 88.90585,
#   'Z': 39,
#   'group': 3,
#   'fusion_heat': 11.5,
#   'evaporation_heat': 367.0,
#   'specific_heat': 0.298,
#   'row': 5,
#   'mendeleev_no': 25.0,
#   'iupac_ordering': 48,
#   'average_ionic_radius': 1.04,
#   'atomic_radius': 1.8,
#   'atomic_radius_calculated': 2.12,
#   'van_der_waals_radius': 2.32,
#   'X': 1.22,
#   'electron_affinity': 0.3112922,
#   'ionization_energy': 6.21726,
#   'valence': 3,
#   'density_of_solid': 4472.0,
#   'molar_volume': 19.88,
#   'boiling_point': 3618.15,
#   'melting_point': 1799.0,
#   'thermal_conductivity': 17.0},
#  'C': {'atomic_mass': 12.0107,
#   'Z': 6,
#   'group': 14,
#   'fusion_heat': 117,
#   'evaporation_heat': 715,
#   'specific_heat': 0.709,
#   'row': 2,
#   'mendeleev_no': 95.0,
#   'iupac_ordering': 86,
#   'average_ionic_radius': 0.3,
#   'atomic_radius': 0.7,
#   'atomic_radius_calculated': 0.67,
#   'van_der_waals_radius': 1.7,
#   'X': 2.55,
#   'electron_affinity': 1.262122611,
#   'ionization_energy': 11.260288,
#   'valence': 4,
#   'density_of_solid': 2267.0,
#   'molar_volume': 5.29,
#   'boiling_point': 4098.15,
#   'melting_point': 3800.0,
#   'thermal_conductivity': 140.0},
#  'Si': {'atomic_mass': 28.0855,
#   'Z': 14,
#   'group': 14,
#   'fusion_heat': 50.6,
#   'evaporation_heat': 383.0,
#   'specific_heat': 0.712,
#   'row': 3,
#   'mendeleev_no': 85.0,
#   'iupac_ordering': 85,
#   'average_ionic_radius': 0.54,
#   'atomic_radius': 1.1,
#   'atomic_radius_calculated': 1.11,
#   'van_der_waals_radius': 2.1,
#   'X': 1.9,
#   'electron_affinity': 1.38952128,
#   'ionization_energy': 8.15168,
#   'valence': 4,
#   'density_of_solid': 2330.0,
#   'molar_volume': 12.06,
#   'boiling_point': 3538.15,
#   'melting_point': 1687.0,
#   'thermal_conductivity': 150.0},
#  'B': {'atomic_mass': 10.811,
#   'Z': 5,
#   'group': 13,
#   'fusion_heat': 23.6,
#   'evaporation_heat': 504.5,
#   'specific_heat': 1.026,
#   'row': 2,
#   'mendeleev_no': 86.0,
#   'iupac_ordering': 81,
#   'average_ionic_radius': 0.41,
#   'atomic_radius': 0.85,
#   'atomic_radius_calculated': 0.87,
#   'van_der_waals_radius': 1.92,
#   'X': 2.04,
#   'electron_affinity': 0.27972325,
#   'ionization_energy': 8.298019,
#   'valence': 3,
#   'density_of_solid': 2460.0,
#   'molar_volume': 4.39,
#   'boiling_point': 4273.15,
#   'melting_point': 2349.0,
#   'thermal_conductivity': 27.0},
#  'Hf': {'atomic_mass': 178.49,
#   'Z': 72,
#   'group': 4,
#   'fusion_heat': 25.1,
#   'evaporation_heat': 575.0,
#   'specific_heat': 0.144,
#   'row': 6,
#   'mendeleev_no': 50.0,
#   'iupac_ordering': 50,
#   'average_ionic_radius': 0.85,
#   'atomic_radius': 1.55,
#   'atomic_radius_calculated': 2.08,
#   'van_der_waals_radius': 2.23,
#   'X': 1.3,
#   'electron_affinity': 0.17807,
#   'ionization_energy': 6.82507,
#   'valence': 4,
#   'density_of_solid': 13310.0,
#   'molar_volume': 13.44,
#   'boiling_point': 4873.15,
#   'melting_point': 2506.0,
#   'thermal_conductivity': 23.0},
#  'Pd': {'atomic_mass': 106.42,
#   'Z': 46,
#   'group': 10,
#   'fusion_heat': 17.24,
#   'evaporation_heat': 372.4,
#   'specific_heat': 0.246,
#   'row': 5,
#   'mendeleev_no': 69.0,
#   'iupac_ordering': 69,
#   'average_ionic_radius': 0.84625,
#   'atomic_radius': 1.4,
#   'atomic_radius_calculated': 1.69,
#   'van_der_waals_radius': 2.1,
#   'X': 2.2,
#   'electron_affinity': 0.5621412,
#   'ionization_energy': 8.336839,
#   'valence': 10,
#   'density_of_solid': 12023.0,
#   'molar_volume': 8.56,
#   'boiling_point': 3236.15,
#   'melting_point': 1828.05,
#   'thermal_conductivity': 72.0},
#  'Zr': {'atomic_mass': 91.224,
#   'Z': 40,
#   'group': 4,
#   'fusion_heat': 19.2,
#   'evaporation_heat': 567.0,
#   'specific_heat': 0.278,
#   'row': 5,
#   'mendeleev_no': 49.0,
#   'iupac_ordering': 51,
#   'average_ionic_radius': 0.86,
#   'atomic_radius': 1.55,
#   'atomic_radius_calculated': 2.06,
#   'van_der_waals_radius': 2.23,
#   'X': 1.33,
#   'electron_affinity': 0.433289,
#   'ionization_energy': 6.634126,
#   'valence': 4,
#   'density_of_solid': 6511.0,
#   'molar_volume': 14.02,
#   'boiling_point': 4679.15,
#   'melting_point': 2128.0,
#   'thermal_conductivity': 23.0},
#  'Sc': {'atomic_mass': 44.955912,
#   'Z': 21,
#   'group': 3,
#   'fusion_heat': 15.8,
#   'evaporation_heat': 332.7,
#   'specific_heat': 0.568,
#   'row': 4,
#   'mendeleev_no': 19.0,
#   'iupac_ordering': 49,
#   'average_ionic_radius': 0.885,
#   'atomic_radius': 1.6,
#   'atomic_radius_calculated': 1.84,
#   'van_der_waals_radius': 2.15,
#   'X': 1.36,
#   'electron_affinity': 0.17938023,
#   'ionization_energy': 6.56149,
#   'valence': 3,
#   'density_of_solid': 2985.0,
#   'molar_volume': 15.0,
#   'boiling_point': 3109.15,
#   'melting_point': 1814.0,
#   'thermal_conductivity': 16.0},
#  'V': {'atomic_mass': 50.9415,
#   'Z': 23,
#   'group': 5,
#   'fusion_heat': 17.5,
#   'evaporation_heat': 460.0,
#   'specific_heat': 0.489,
#   'row': 4,
#   'mendeleev_no': 54.0,
#   'iupac_ordering': 55,
#   'average_ionic_radius': 0.7775,
#   'atomic_radius': 1.35,
#   'atomic_radius_calculated': 1.71,
#   'van_der_waals_radius': 2.07,
#   'X': 1.63,
#   'electron_affinity': 0.527662,
#   'ionization_energy': 6.746187,
#   'valence': 5,
#   'density_of_solid': 6110.0,
#   'molar_volume': 8.32,
#   'boiling_point': 3680.15,
#   'melting_point': 2183.0,
#   'thermal_conductivity': 31.0},
#  'Ge': {'atomic_mass': 72.64,
#   'Z': 32,
#   'group': 14,
#   'fusion_heat': 36.8,
#   'evaporation_heat': 328.0,
#   'specific_heat': 0.32,
#   'row': 4,
#   'mendeleev_no': 84.0,
#   'iupac_ordering': 84,
#   'average_ionic_radius': 0.77,
#   'atomic_radius': 1.25,
#   'atomic_radius_calculated': 1.25,
#   'van_der_waals_radius': 2.11,
#   'X': 2.01,
#   'electron_affinity': 1.232676413,
#   'ionization_energy': 7.899435,
#   'valence': 4,
#   'density_of_solid': 5323.0,
#   'molar_volume': 13.63,
#   'boiling_point': 3106.15,
#   'melting_point': 1211.4,
#   'thermal_conductivity': 60.0},
#  'Hg': {'atomic_mass': 200.59,
#   'Z': 80,
#   'group': 12,
#   'fusion_heat': 2.295,
#   'evaporation_heat': 58.5,
#   'specific_heat': 0.14,
#   'row': 6,
#   'mendeleev_no': 74.0,
#   'iupac_ordering': 74,
#   'average_ionic_radius': 1.245,
#   'atomic_radius': 1.5,
#   'atomic_radius_calculated': 1.71,
#   'van_der_waals_radius': 2.23,
#   'X': 2,
#   'electron_affinity': -0.52,
#   'ionization_energy': 10.437504,
#   'valence': 2,
#   'density_of_solid': 14236.337828246984,
#   'molar_volume': 14.09,
#   'boiling_point': 629.769,
#   'melting_point': 234.32,
#   'thermal_conductivity': 8.3},
#  'Tl': {'atomic_mass': 204.3833,
#   'Z': 81,
#   'group': 13,
#   'fusion_heat': 4.31,
#   'evaporation_heat': 162.4,
#   'specific_heat': 0.129,
#   'row': 6,
#   'mendeleev_no': 78.0,
#   'iupac_ordering': 77,
#   'average_ionic_radius': 1.3325,
#   'atomic_radius': 1.9,
#   'atomic_radius_calculated': 1.56,
#   'van_der_waals_radius': 1.96,
#   'X': 1.62,
#   'electron_affinity': 0.32005319,
#   'ionization_energy': 6.1082873,
#   'valence': 3,
#   'density_of_solid': 11850.0,
#   'molar_volume': 17.22,
#   'boiling_point': 1746.15,
#   'melting_point': 577.0,
#   'thermal_conductivity': 46.0},
#  'Au': {'atomic_mass': 196.966569,
#   'Z': 79,
#   'group': 11,
#   'fusion_heat': 12.68,
#   'evaporation_heat': 340.0,
#   'specific_heat': 0.129,
#   'row': 6,
#   'mendeleev_no': 70.0,
#   'iupac_ordering': 71,
#   'average_ionic_radius': 1.07,
#   'atomic_radius': 1.35,
#   'atomic_radius_calculated': 1.74,
#   'van_der_waals_radius': 2.14,
#   'X': 2.54,
#   'electron_affinity': 2.30861025,
#   'ionization_energy': 9.225554,
#   'valence': 11,
#   'density_of_solid': 19300.0,
#   'molar_volume': 10.21,
#   'boiling_point': 3109.15,
#   'melting_point': 1337.33,
#   'thermal_conductivity': 320.0},
#  'Cs': {'atomic_mass': 132.9054519,
#   'Z': 55,
#   'group': 1,
#   'fusion_heat': 2.09,
#   'evaporation_heat': 68.3,
#   'specific_heat': 0.242,
#   'row': 6,
#   'mendeleev_no': 8.0,
#   'iupac_ordering': 7,
#   'average_ionic_radius': 1.81,
#   'atomic_radius': 2.6,
#   'atomic_radius_calculated': 2.98,
#   'van_der_waals_radius': 3.43,
#   'X': 0.79,
#   'electron_affinity': 0.471598338,
#   'ionization_energy': 3.89390572743,
#   'valence': 1,
#   'density_of_solid': 1879.0,
#   'molar_volume': 70.94,
#   'boiling_point': 944.15,
#   'melting_point': 301.59,
#   'thermal_conductivity': 36.0},
#  'Br': {'atomic_mass': 79.904,
#   'Z': 35,
#   'group': 17,
#   'fusion_heat': 10.57,
#   'evaporation_heat': 29.56,
#   'specific_heat': 0.474,
#   'row': 4,
#   'mendeleev_no': 98.0,
#   'iupac_ordering': 100,
#   'average_ionic_radius': 0.8825000000000001,
#   'atomic_radius': 1.15,
#   'atomic_radius_calculated': 0.94,
#   'van_der_waals_radius': 1.85,
#   'X': 2.96,
#   'electron_affinity': 3.3635883,
#   'ionization_energy': 11.81381,
#   'valence': 7,
#   'density_of_solid': 4039.6359959555107,
#   'molar_volume': 19.78,
#   'boiling_point': 331.95,
#   'melting_point': 265.8,
#   'thermal_conductivity': 0.12},
#  'K': {'atomic_mass': 39.0983,
#   'Z': 19,
#   'group': 1,
#   'fusion_heat': 102.5,
#   'evaporation_heat': 2.33,
#   'specific_heat': 0.757,
#   'row': 4,
#   'mendeleev_no': 10.0,
#   'iupac_ordering': 9,
#   'average_ionic_radius': 1.52,
#   'atomic_radius': 2.2,
#   'atomic_radius_calculated': 2.43,
#   'van_der_waals_radius': 2.75,
#   'X': 0.82,
#   'electron_affinity': 0.50145913,
#   'ionization_energy': 4.34066373,
#   'valence': 1,
#   'density_of_solid': 856.0,
#   'molar_volume': 45.94,
#   'boiling_point': 1032.15,
#   'melting_point': 336.53,
#   'thermal_conductivity': 100.0},
#  'Rh': {'atomic_mass': 102.9055,
#   'Z': 45,
#   'group': 9,
#   'fusion_heat': 21.8,
#   'evaporation_heat': 494.0,
#   'specific_heat': 0.243,
#   'row': 5,
#   'mendeleev_no': 65.0,
#   'iupac_ordering': 66,
#   'average_ionic_radius': 0.745,
#   'atomic_radius': 1.35,
#   'atomic_radius_calculated': 1.73,
#   'van_der_waals_radius': 2.1,
#   'X': 2.28,
#   'electron_affinity': 1.142892,
#   'ionization_energy': 7.4589,
#   'valence': 9,
#   'density_of_solid': 12450.0,
#   'molar_volume': 8.28,
#   'boiling_point': 3968.15,
#   'melting_point': 2237.0,
#   'thermal_conductivity': 150.0},
#  'Ga': {'atomic_mass': 69.723,
#   'Z': 31,
#   'group': 13,
#   'fusion_heat': 5.59,
#   'evaporation_heat': 270.3,
#   'specific_heat': 0.373,
#   'row': 4,
#   'mendeleev_no': 81.0,
#   'iupac_ordering': 79,
#   'average_ionic_radius': 0.76,
#   'atomic_radius': 1.3,
#   'atomic_radius_calculated': 1.36,
#   'van_der_waals_radius': 1.87,
#   'X': 1.81,
#   'electron_affinity': 0.30116615,
#   'ionization_energy': 5.999302,
#   'valence': 3,
#   'density_of_solid': 5904.0,
#   'molar_volume': 11.8,
#   'boiling_point': 2502.15,
#   'melting_point': 302.91,
#   'thermal_conductivity': 29.0},
#  'Rb': {'atomic_mass': 85.4678,
#   'Z': 37,
#   'group': 1,
#   'fusion_heat': 2.2,
#   'evaporation_heat': 75.8,
#   'specific_heat': 0.363,
#   'row': 5,
#   'mendeleev_no': 9.0,
#   'iupac_ordering': 8,
#   'average_ionic_radius': 1.66,
#   'atomic_radius': 2.35,
#   'atomic_radius_calculated': 2.65,
#   'van_der_waals_radius': 3.03,
#   'X': 0.82,
#   'electron_affinity': 0.48591621,
#   'ionization_energy': 4.1771281,
#   'valence': 1,
#   'density_of_solid': 1532.0,
#   'molar_volume': 55.76,
#   'boiling_point': 961.15,
#   'melting_point': 312.46,
#   'thermal_conductivity': 58.0},
#  'Ir': {'atomic_mass': 192.217,
#   'Z': 77,
#   'group': 9,
#   'fusion_heat': 27.61,
#   'evaporation_heat': 604.0,
#   'specific_heat': 0.131,
#   'row': 6,
#   'mendeleev_no': 66.0,
#   'iupac_ordering': 65,
#   'average_ionic_radius': 0.765,
#   'atomic_radius': 1.35,
#   'atomic_radius_calculated': 1.8,
#   'van_der_waals_radius': 2.13,
#   'X': 2.2,
#   'electron_affinity': 1.56405712,
#   'ionization_energy': 8.96702,
#   'valence': 9,
#   'density_of_solid': 22650.0,
#   'molar_volume': 8.52,
#   'boiling_point': 4701.15,
#   'melting_point': 2739.0,
#   'thermal_conductivity': 150.0},
#  'Th': {'atomic_mass': 232.03806,
#   'Z': 90,
#   'group': 3,
#   'fusion_heat': 16.11,
#   'evaporation_heat': 513.7,
#   'specific_heat': 0.118,
#   'row': 7,
#   'mendeleev_no': 47.0,
#   'iupac_ordering': 31,
#   'average_ionic_radius': 1.08,
#   'atomic_radius': 1.8,
#   'atomic_radius_calculated': 1.8,
#   'van_der_waals_radius': 2.45,
#   'X': 1.3,
#   'electron_affinity': 0.607696,
#   'ionization_energy': 6.3067,
#   'valence': 4,
#   'density_of_solid': 11724.0,
#   'molar_volume': 19.8,
#   'boiling_point': 5058.15,
#   'melting_point': 2115.0,
#   'thermal_conductivity': 54.0},
#  'Yb': {'atomic_mass': 173.04,
#   'Z': 70,
#   'group': 3,
#   'fusion_heat': 3.35,
#   'evaporation_heat': 159.0,
#   'specific_heat': 0.155,
#   'row': 6,
#   'mendeleev_no': 17.0,
#   'iupac_ordering': 34,
#   'average_ionic_radius': 1.084,
#   'atomic_radius': 1.75,
#   'atomic_radius_calculated': 2.22,
#   'van_der_waals_radius': 2.26,
#   'X': 1.1,
#   'electron_affinity': -0.02,
#   'ionization_energy': 6.25416,
#   'valence': 14,
#   'density_of_solid': 6570.0,
#   'molar_volume': 24.84,
#   'boiling_point': 1469.15,
#   'melting_point': 1097.0,
#   'thermal_conductivity': 39.0}}

# %%
#print dataframe to csv
df.to_csv('A2BCX6_filtered_with_properties.csv')
